# %%
import pandas as pd
train_enhanced = pd.read_csv('../data/train_enhanced.csv', sep = ',')
eval_enhanced = pd.read_csv('../data/eval_enhanced.csv', sep = ',')

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sksurv.metrics import concordance_index_censored
from sksurv.linear_model import CoxPHSurvivalAnalysis
from sksurv.util import Surv

time_col = "OS_YEARS"
event_col = "OS_STATUS"

# Build feature matrix X by dropping time/event/ID from train_enhanced
exclude_cols = {time_col, event_col, "ID"}
feature_cols = [c for c in train_enhanced.columns if c not in exclude_cols]




X = train_enhanced[feature_cols].to_numpy(dtype=float, na_value=0.0)

time_vals = train_enhanced[time_col].to_numpy(dtype=float)
event_vals = train_enhanced[event_col].to_numpy(dtype=bool)

df = pd.DataFrame({
    'time': time_vals,
    'event': event_vals
})

y = Surv.from_dataframe("event", "time", df)

# %% [markdown]
# Résumé du plan:
# - Préparer les données à partir de train_enhanced et y (temps et statut).
# - Entraîner un XGB AFT avec K-fold cross-validation (K=5 par défaut) et évaluer les scores via concordance (C-index).
# - Former le modèle sur l’ensemble des données et faire des prédictions sur le jeu d’évaluation, en générant un CSV avec les colonnes "ID" et "risk_score" (risque = opposé du temps de survie).
# - Sauvegarder le CSV final dans le répertoire approprié.

# %%
# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import KFold
from sksurv.metrics import concordance_index_censored
import xgboost as xgb  # <--- ajout important

# Chargement des données existantes
train_enhanced = pd.read_csv('../data/train_enhanced.csv', sep=',')
eval_enhanced = pd.read_csv('../data/eval_enhanced.csv', sep=',')

time_col = "OS_YEARS"
event_col = "OS_STATUS"
exclude_cols = {time_col, event_col, "ID"}
feature_cols = [c for c in train_enhanced.columns if c not in exclude_cols]

X = train_enhanced[feature_cols].fillna(0.0).to_numpy(dtype=float)
time_vals = train_enhanced[time_col].to_numpy(dtype=float)     # temps bruts
event_vals = train_enhanced[event_col].to_numpy(dtype=bool)    # 1 = event, 0 = censuré

# Préparer y pour XGBoost AFT : log(1 + temps)
y_log_time = np.log1p(time_vals)

# %%
# Paramètres AFT
params = {
    "objective": "survival:aft",
    "eval_metric": "aft-nloglik",
    "learning_rate": 0.05,
    "max_depth": 4,
    "subsample": 0.8,
    "colsample_bytree": 0.8,
    "min_child_weight": 1,
    "gamma": 0.0,
    "aft_loss_distribution": "normal",
    "aft_loss_distribution_scale": 1.0,
    "tree_method": "hist",
    "seed": 42,
}

num_boost_round = 200

n_splits = 5
kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)

c_indices = []
fold = 1

for train_idx, val_idx in kf.split(X):
    X_train, X_val = X[train_idx], X[val_idx]
    y_train_log, y_val_log = y_log_time[train_idx], y_log_time[val_idx]
    e_train, e_val = event_vals[train_idx], event_vals[val_idx]

    # Bornes inf / sup en log-temps :
    # - non censuré : [log(t), log(t)]
    # - censuré à droite : [log(t), +inf]
    lb_train = y_train_log.copy()
    ub_train = y_train_log.copy()
    ub_train[e_train == 0] = np.inf

    lb_val = y_val_log.copy()
    ub_val = y_val_log.copy()
    ub_val[e_val == 0] = np.inf

    dtrain = xgb.DMatrix(X_train)
    dtrain.set_float_info("label_lower_bound", lb_train)
    dtrain.set_float_info("label_upper_bound", ub_train)

    dval = xgb.DMatrix(X_val)
    dval.set_float_info("label_lower_bound", lb_val)
    dval.set_float_info("label_upper_bound", ub_val)

    model = xgb.train(
        params,
        dtrain,
        num_boost_round=num_boost_round,
        evals=[(dval, "valid")],
        verbose_eval=False,
    )

    # Prédictions de log-temps sur la validation
    y_pred_log = model.predict(dval)

    # C-index : on prend -y_pred_log comme "risque"
    c_index = concordance_index_censored(
    e_val.astype(bool),      # event_indicator
    time_vals[val_idx],      # event_time
    -y_pred_log)[0]


    c_indices.append(c_index)
    print(f"Fold {fold} — C-index: {c_index:.4f}")
    fold += 1

print("\nC-index moyen :", np.mean(c_indices))
# Out:
# Fold 1 — C-index: 0.7541
# Fold 2 — C-index: 0.7093
# Fold 3 — C-index: 0.7350
# Fold 4 — C-index: 0.7252
# Fold 5 — C-index: 0.7211
#
# C-index moyen : 0.7289423518683573

# %% [markdown]
# ## Entraînement sur l'ensemble complet et prédiction

# %%
X_full = train_enhanced[feature_cols].fillna(0.0).to_numpy(dtype=float)
y_full_log_time = np.log1p(time_vals)

lb_full = y_full_log_time.copy()
ub_full = y_full_log_time.copy()
ub_full[event_vals == 0] = np.inf

dfull = xgb.DMatrix(X_full)
dfull.set_float_info("label_lower_bound", lb_full)
dfull.set_float_info("label_upper_bound", ub_full)

model_full = xgb.train(
    params,
    dfull,
    num_boost_round=num_boost_round,
    verbose_eval=False
)

# %% [markdown]
# ## Tuning des hyperparamètres XGBoost AFT avec Optuna

# %%
# !pip install optuna

# %%
import optuna
from sklearn.model_selection import KFold
import numpy as np
import xgboost as xgb
from sksurv.metrics import concordance_index_censored

# %%
def objective(trial):
    params = {
        "objective": "survival:aft",
        "eval_metric": "aft-nloglik",
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3, log=True),
        "max_depth": trial.suggest_int("max_depth", 3, 10),
        "subsample": trial.suggest_float("subsample", 0.5, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.5, 1.0),
        "min_child_weight": trial.suggest_int("min_child_weight", 1, 10),
        "gamma": trial.suggest_float("gamma", 0.0, 5.0),
        "aft_loss_distribution": trial.suggest_categorical("aft_loss_distribution", ["normal", "logistic", "extreme"]),
        "aft_loss_distribution_scale": trial.suggest_float("aft_loss_distribution_scale", 0.5, 2.0),
        "tree_method": "hist",
        "seed": 42,
    }

    num_boost_round = trial.suggest_int("num_boost_round", 50, 500)

    n_splits = 5
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)

    c_indices = []

    for train_idx, val_idx in kf.split(X):
        X_train_fold, X_val_fold = X[train_idx], X[val_idx]
        y_train_log_fold, y_val_log_fold = y_log_time[train_idx], y_log_time[val_idx]
        e_train_fold, e_val_fold = event_vals[train_idx], event_vals[val_idx]

        lb_train_fold = y_train_log_fold.copy()
        ub_train_fold = y_train_log_fold.copy()
        ub_train_fold[e_train_fold == 0] = np.inf

        lb_val_fold = y_val_log_fold.copy()
        ub_val_fold = y_val_log_fold.copy()
        ub_val_fold[e_val_fold == 0] = np.inf

        dtrain_fold = xgb.DMatrix(X_train_fold)
        dtrain_fold.set_float_info("label_lower_bound", lb_train_fold)
        dtrain_fold.set_float_info("label_upper_bound", ub_train_fold)

        dval_fold = xgb.DMatrix(X_val_fold)
        dval_fold.set_float_info("label_lower_bound", lb_val_fold)
        dval_fold.set_float_info("label_upper_bound", ub_val_fold)

        model_fold = xgb.train(
            params,
            dtrain_fold,
            num_boost_round=num_boost_round,
            evals=[(dval_fold, "valid")],
            verbose_eval=False,
        )

        y_pred_log_fold = model_fold.predict(dval_fold)

        c_index = concordance_index_censored(
            e_val_fold.astype(bool),
            time_vals[val_idx],
            -y_pred_log_fold
        )[0]

        c_indices.append(c_index)

    return np.mean(c_indices)

# %%
study = optuna.create_study(direction="maximize", study_name="xgb_aft_tuning")
study.optimize(objective, n_trials=100, show_progress_bar=True)
# Out:
# [I 2025-11-23 23:50:20,875] A new study created in memory with name: xgb_aft_tuning
#   0%|          | 0/100 [00:00<?, ?it/s]
# [I 2025-11-23 23:50:25,116] Trial 0 finished with value: 0.7340911317423737 and parameters: {'learning_rate': 0.01016660929538919, 'max_depth': 7, 'subsample': 0.6294781908917063, 'colsample_bytree': 0.766046374091054, 'min_child_weight': 3, 'gamma': 0.17102770620736063, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 1.2298783332313654, 'num_boost_round': 330}. Best is trial 0 with value: 0.7340911317423737.
# [I 2025-11-23 23:50:25,685] Trial 1 finished with value: 0.7245250420531211 and parameters: {'learning_rate': 0.022448611158705282, 'max_depth': 3, 'subsample': 0.6516761104217552, 'colsample_bytree': 0.8376067710749797, 'min_child_weight': 5, 'gamma': 2.923818401814335, 'aft_loss_distribution': 'extreme', 'aft_loss_distribution_scale': 1.4356545180572307, 'num_boost_round': 81}. Best is trial 0 with value: 0.7340911317423737.
# [I 2025-11-23 23:50:28,420] Trial 2 finished with value: 0.7333719426266254 and parameters: {'learning_rate': 0.012557996606721833, 'max_depth': 6, 'subsample': 0.9282208856616427, 'colsample_bytree': 0.6275454708912663, 'min_child_weight': 7, 'gamma': 3.964968405315185, 'aft_loss_distribution': 'extreme', 'aft_loss_distribution_scale': 1.065186297962223, 'num_boost_round': 424}. Best is trial 0 with value: 0.7340911317423737.
# [I 2025-11-23 23:50:29,145] Trial 3 finished with value: 0.7306367177926175 and parameters: {'learning_rate': 0.053917655330764404, 'max_depth': 3, 'subsample': 0.8551259095951316, 'colsample_bytree': 0.8564068673835208, 'min_child_weight': 10, 'gamma': 0.5717501358580651, 'aft_loss_distribution': 'logistic', 'aft_loss_distribution_scale': 1.6133609818741896, 'num_boost_round': 117}. Best is trial 0 with value: 0.7340911317423737.
# [I 2025-11-23 23:50:31,585] Trial 4 finished with value: 0.7327998263565543 and parameters: {'learning_rate': 0.016910865131737278, 'max_depth': 7, 'subsample': 0.8673227812301392, 'colsample_bytree': 0.7482365562274165, 'min_child_weight': 6, 'gamma': 2.2331799927352995, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 1.4483919815503934, 'num_boost_round': 335}. Best is trial 0 with value: 0.7340911317423737.
# [I 2025-11-23 23:50:32,410] Trial 5 finished with value: 0.7312121890572311 and parameters: {'learning_rate': 0.042350974750931025, 'max_depth': 8, 'subsample': 0.7326753010474741, 'colsample_bytree': 0.9117578036626901, 'min_child_weight': 1, 'gamma': 2.033981023179678, 'aft_loss_distribution': 'logistic', 'aft_loss_distribution_scale': 1.700870266674982, 'num_boost_round': 84}. Best is trial 0 with value: 0.7340911317423737.
# [I 2025-11-23 23:50:37,682] Trial 6 finished with value: 0.7354559055741333 and parameters: {'learning_rate': 0.010432754789529068, 'max_depth': 10, 'subsample': 0.5114992196558441, 'colsample_bytree': 0.6604915292388518, 'min_child_weight': 5, 'gamma': 2.0614510353381137, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 1.0689640622507492, 'num_boost_round': 472}. Best is trial 6 with value: 0.7354559055741333.
# [I 2025-11-23 23:50:39,948] Trial 7 finished with value: 0.7318595403942273 and parameters: {'learning_rate': 0.028912715654659586, 'max_depth': 6, 'subsample': 0.6985356500059379, 'colsample_bytree': 0.7218667614548261, 'min_child_weight': 1, 'gamma': 2.2429179319744104, 'aft_loss_distribution': 'extreme', 'aft_loss_distribution_scale': 1.5668056774948693, 'num_boost_round': 385}. Best is trial 6 with value: 0.7354559055741333.
# [I 2025-11-23 23:50:42,236] Trial 8 finished with value: 0.7084797219760948 and parameters: {'learning_rate': 0.10646032048744902, 'max_depth': 5, 'subsample': 0.9282695146840211, 'colsample_bytree': 0.5860957630589676, 'min_child_weight': 8, 'gamma': 0.12982852743698592, 'aft_loss_distribution': 'extreme', 'aft_loss_distribution_scale': 1.6292241063268675, 'num_boost_round': 318}. Best is trial 6 with value: 0.7354559055741333.
# [I 2025-11-23 23:50:43,356] Trial 9 finished with value: 0.7267751418800774 and parameters: {'learning_rate': 0.11498965713719243, 'max_depth': 10, 'subsample': 0.8312931993400945, 'colsample_bytree': 0.8851607275862363, 'min_child_weight': 9, 'gamma': 2.6419641445952733, 'aft_loss_distribution': 'extreme', 'aft_loss_distribution_scale': 1.3427348492864153, 'num_boost_round': 262}. Best is trial 6 with value: 0.7354559055741333.
# [I 2025-11-23 23:50:45,277] Trial 10 finished with value: 0.6891206359672039 and parameters: {'learning_rate': 0.2863402983968117, 'max_depth': 10, 'subsample': 0.5097586310472391, 'colsample_bytree': 0.5190561455037539, 'min_child_weight': 4, 'gamma': 4.692277022308754, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 0.577197883275496, 'num_boost_round': 462}. Best is trial 6 with value: 0.7354559055741333.
# [I 2025-11-23 23:50:48,534] Trial 11 finished with value: 0.7348288451859505 and parameters: {'learning_rate': 0.010309454244835675, 'max_depth': 8, 'subsample': 0.5171707798629385, 'colsample_bytree': 0.675086388348872, 'min_child_weight': 3, 'gamma': 1.1914072014851198, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 1.0047432439187716, 'num_boost_round': 223}. Best is trial 6 with value: 0.7354559055741333.
# [I 2025-11-23 23:50:51,900] Trial 12 finished with value: 0.733065631260209 and parameters: {'learning_rate': 0.018061189003383216, 'max_depth': 9, 'subsample': 0.5064758845597345, 'colsample_bytree': 0.6578944351924519, 'min_child_weight': 3, 'gamma': 1.2720126325810839, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 0.8953352973468679, 'num_boost_round': 193}. Best is trial 6 with value: 0.7354559055741333.
# [I 2025-11-23 23:50:55,850] Trial 13 finished with value: 0.7342618816526704 and parameters: {'learning_rate': 0.010654682645853546, 'max_depth': 9, 'subsample': 0.5663138037809031, 'colsample_bytree': 0.6690462399388935, 'min_child_weight': 3, 'gamma': 1.4007708437736075, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 0.8101419629728723, 'num_boost_round': 191}. Best is trial 6 with value: 0.7354559055741333.
# [I 2025-11-23 23:50:57,078] Trial 14 finished with value: 0.733612727641135 and parameters: {'learning_rate': 0.03303307893644356, 'max_depth': 9, 'subsample': 0.582488076200677, 'colsample_bytree': 0.5588543131488455, 'min_child_weight': 5, 'gamma': 3.347920636982916, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 1.932157012106646, 'num_boost_round': 231}. Best is trial 6 with value: 0.7354559055741333.
# [I 2025-11-23 23:50:59,947] Trial 15 finished with value: 0.7185560102322307 and parameters: {'learning_rate': 0.09855909974198387, 'max_depth': 8, 'subsample': 0.5794200326049908, 'colsample_bytree': 0.701821869246505, 'min_child_weight': 2, 'gamma': 1.309751081055722, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 1.0856713890613834, 'num_boost_round': 476}. Best is trial 6 with value: 0.7354559055741333.
# [I 2025-11-23 23:51:03,308] Trial 16 finished with value: 0.7289348326306853 and parameters: {'learning_rate': 0.015976439829636205, 'max_depth': 10, 'subsample': 0.7889111705938681, 'colsample_bytree': 0.9730152928354531, 'min_child_weight': 6, 'gamma': 0.9476912821810735, 'aft_loss_distribution': 'logistic', 'aft_loss_distribution_scale': 0.7421775575611698, 'num_boost_round': 160}. Best is trial 6 with value: 0.7354559055741333.
# [I 2025-11-23 23:51:06,821] Trial 17 finished with value: 0.7292885901993944 and parameters: {'learning_rate': 0.025111487349870405, 'max_depth': 8, 'subsample': 0.6522892070847317, 'colsample_bytree': 0.7849108710592411, 'min_child_weight': 4, 'gamma': 1.855010684778906, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 1.0163167556113542, 'num_boost_round': 404}. Best is trial 6 with value: 0.7354559055741333.
# [I 2025-11-23 23:51:08,344] Trial 18 finished with value: 0.6953693176707647 and parameters: {'learning_rate': 0.20877172743530073, 'max_depth': 5, 'subsample': 0.5399446971248971, 'colsample_bytree': 0.6134646189432996, 'min_child_weight': 7, 'gamma': 2.9556062759591026, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 0.6250038977201885, 'num_boost_round': 275}. Best is trial 6 with value: 0.7354559055741333.
# [I 2025-11-23 23:51:11,072] Trial 19 finished with value: 0.7348538304360769 and parameters: {'learning_rate': 0.014761266576069621, 'max_depth': 9, 'subsample': 0.9904518461644395, 'colsample_bytree': 0.5244891533772869, 'min_child_weight': 4, 'gamma': 3.514603657690361, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 1.2079015641165352, 'num_boost_round': 361}. Best is trial 6 with value: 0.7354559055741333.
# [I 2025-11-23 23:51:12,606] Trial 20 finished with value: 0.7331183600854739 and parameters: {'learning_rate': 0.07445338329252818, 'max_depth': 9, 'subsample': 0.9740873555690248, 'colsample_bytree': 0.5064938135105947, 'min_child_weight': 4, 'gamma': 3.7604460466401832, 'aft_loss_distribution': 'logistic', 'aft_loss_distribution_scale': 1.233743578500682, 'num_boost_round': 371}. Best is trial 6 with value: 0.7354559055741333.
# [I 2025-11-23 23:51:15,406] Trial 21 finished with value: 0.7365586199684993 and parameters: {'learning_rate': 0.013790330238020424, 'max_depth': 8, 'subsample': 0.6197955032312261, 'colsample_bytree': 0.5557712105833437, 'min_child_weight': 2, 'gamma': 4.7457964169034454, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 1.1456793838203834, 'num_boost_round': 497}. Best is trial 21 with value: 0.7365586199684993.
# [I 2025-11-23 23:51:17,802] Trial 22 finished with value: 0.7362022820923559 and parameters: {'learning_rate': 0.014747188788328395, 'max_depth': 10, 'subsample': 0.6149458848855864, 'colsample_bytree': 0.5547503967542152, 'min_child_weight': 2, 'gamma': 4.9612715649976336, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 1.1845687855701172, 'num_boost_round': 441}. Best is trial 21 with value: 0.7365586199684993.
# [I 2025-11-23 23:51:20,631] Trial 23 finished with value: 0.7359046642882985 and parameters: {'learning_rate': 0.021137274860561845, 'max_depth': 10, 'subsample': 0.6183322750804097, 'colsample_bytree': 0.5715550665697164, 'min_child_weight': 2, 'gamma': 4.976756814627127, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 0.8951958412217991, 'num_boost_round': 497}. Best is trial 21 with value: 0.7365586199684993.
# [I 2025-11-23 23:51:23,469] Trial 24 finished with value: 0.7372918139132384 and parameters: {'learning_rate': 0.020316175899216884, 'max_depth': 10, 'subsample': 0.6933432702285451, 'colsample_bytree': 0.5641570590005562, 'min_child_weight': 2, 'gamma': 4.967201038815009, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 0.8901460812259246, 'num_boost_round': 499}. Best is trial 24 with value: 0.7372918139132384.
# [I 2025-11-23 23:51:25,689] Trial 25 finished with value: 0.7323915084021777 and parameters: {'learning_rate': 0.035772576162174566, 'max_depth': 7, 'subsample': 0.6720748418857178, 'colsample_bytree': 0.5505495577036754, 'min_child_weight': 2, 'gamma': 4.363999958604289, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 0.7566089218718628, 'num_boost_round': 420}. Best is trial 24 with value: 0.7372918139132384.
# [I 2025-11-23 23:51:28,450] Trial 26 finished with value: 0.737089906645848 and parameters: {'learning_rate': 0.01362812992216595, 'max_depth': 9, 'subsample': 0.7313254271507829, 'colsample_bytree': 0.6107430504029151, 'min_child_weight': 1, 'gamma': 4.259307416302697, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 1.1549446628534277, 'num_boost_round': 447}. Best is trial 24 with value: 0.7372918139132384.
# [I 2025-11-23 23:51:31,319] Trial 27 finished with value: 0.735426170173714 and parameters: {'learning_rate': 0.02019598399799403, 'max_depth': 8, 'subsample': 0.7523780626609752, 'colsample_bytree': 0.5994703575327786, 'min_child_weight': 1, 'gamma': 4.258451697386897, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 0.9080838373030247, 'num_boost_round': 499}. Best is trial 24 with value: 0.7372918139132384.
# [I 2025-11-23 23:51:33,536] Trial 28 finished with value: 0.7333729558087461 and parameters: {'learning_rate': 0.01337729200552674, 'max_depth': 9, 'subsample': 0.7117785510902598, 'colsample_bytree': 0.6228464452813587, 'min_child_weight': 1, 'gamma': 4.389747111284226, 'aft_loss_distribution': 'logistic', 'aft_loss_distribution_scale': 1.3580903391205694, 'num_boost_round': 447}. Best is trial 24 with value: 0.7372918139132384.
# [I 2025-11-23 23:51:35,812] Trial 29 finished with value: 0.7356640443405755 and parameters: {'learning_rate': 0.02728533989019328, 'max_depth': 7, 'subsample': 0.7833548014781971, 'colsample_bytree': 0.5014242213786058, 'min_child_weight': 2, 'gamma': 4.55216704235644, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 1.1592144730769078, 'num_boost_round': 494}. Best is trial 24 with value: 0.7372918139132384.
# [I 2025-11-23 23:51:37,507] Trial 30 finished with value: 0.7349251213635115 and parameters: {'learning_rate': 0.05071296957416226, 'max_depth': 8, 'subsample': 0.6871014054349623, 'colsample_bytree': 0.6396237426663401, 'min_child_weight': 3, 'gamma': 3.9970807480441666, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 1.3227534341642273, 'num_boost_round': 323}. Best is trial 24 with value: 0.7372918139132384.
# [I 2025-11-23 23:51:40,511] Trial 31 finished with value: 0.7368043828297907 and parameters: {'learning_rate': 0.01265830649977992, 'max_depth': 10, 'subsample': 0.6113494073814101, 'colsample_bytree': 0.5527612355461152, 'min_child_weight': 2, 'gamma': 4.9994884358364295, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 1.1628996697870613, 'num_boost_round': 441}. Best is trial 24 with value: 0.7372918139132384.
# [I 2025-11-23 23:51:43,735] Trial 32 finished with value: 0.7370546750206619 and parameters: {'learning_rate': 0.013000626416567124, 'max_depth': 9, 'subsample': 0.6319534886580638, 'colsample_bytree': 0.5952019768666665, 'min_child_weight': 1, 'gamma': 4.786217069930356, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 0.9634978870384312, 'num_boost_round': 441}. Best is trial 24 with value: 0.7372918139132384.
# [I 2025-11-23 23:51:46,645] Trial 33 finished with value: 0.7371537138992805 and parameters: {'learning_rate': 0.02168386800342198, 'max_depth': 10, 'subsample': 0.6491251336089358, 'colsample_bytree': 0.5986847855516437, 'min_child_weight': 1, 'gamma': 4.062323699044627, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 0.9556057715937774, 'num_boost_round': 403}. Best is trial 24 with value: 0.7372918139132384.
# [I 2025-11-23 23:51:49,665] Trial 34 finished with value: 0.7341033268139586 and parameters: {'learning_rate': 0.0211348421118364, 'max_depth': 9, 'subsample': 0.6590340699561719, 'colsample_bytree': 0.5889241424775207, 'min_child_weight': 1, 'gamma': 3.991633353451205, 'aft_loss_distribution': 'extreme', 'aft_loss_distribution_scale': 0.6821900900861616, 'num_boost_round': 406}. Best is trial 24 with value: 0.7372918139132384.
# [I 2025-11-23 23:51:55,053] Trial 35 finished with value: 0.7323832337188273 and parameters: {'learning_rate': 0.017659904483832582, 'max_depth': 10, 'subsample': 0.7483481194479774, 'colsample_bytree': 0.7858151042752516, 'min_child_weight': 1, 'gamma': 3.3322457554320275, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 0.5126328707852514, 'num_boost_round': 352}. Best is trial 24 with value: 0.7372918139132384.
# [I 2025-11-23 23:51:57,160] Trial 36 finished with value: 0.7351139026537401 and parameters: {'learning_rate': 0.04082179889349232, 'max_depth': 9, 'subsample': 0.7081860792396493, 'colsample_bytree': 0.6209022157803741, 'min_child_weight': 1, 'gamma': 4.089340677007318, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 0.9933501963012451, 'num_boost_round': 390}. Best is trial 24 with value: 0.7372918139132384.
# [I 2025-11-23 23:51:59,111] Trial 37 finished with value: 0.7357471991795761 and parameters: {'learning_rate': 0.02626196599595567, 'max_depth': 6, 'subsample': 0.7835495463742764, 'colsample_bytree': 0.7155720518645992, 'min_child_weight': 1, 'gamma': 3.697278794864953, 'aft_loss_distribution': 'logistic', 'aft_loss_distribution_scale': 0.9334722868754648, 'num_boost_round': 421}. Best is trial 24 with value: 0.7372918139132384.
# [I 2025-11-23 23:52:03,220] Trial 38 finished with value: 0.7363770275403304 and parameters: {'learning_rate': 0.012064368340034548, 'max_depth': 10, 'subsample': 0.6496515036464076, 'colsample_bytree': 0.6903588879855622, 'min_child_weight': 2, 'gamma': 4.611600072908097, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 0.8084827640546397, 'num_boost_round': 448}. Best is trial 24 with value: 0.7372918139132384.
# [I 2025-11-23 23:52:05,421] Trial 39 finished with value: 0.7325715340505063 and parameters: {'learning_rate': 0.01864469079284066, 'max_depth': 3, 'subsample': 0.8216956078595554, 'colsample_bytree': 0.7430548449135113, 'min_child_weight': 3, 'gamma': 2.9525430011744076, 'aft_loss_distribution': 'extreme', 'aft_loss_distribution_scale': 1.4642638423910093, 'num_boost_round': 469}. Best is trial 24 with value: 0.7372918139132384.
# [I 2025-11-23 23:52:06,913] Trial 40 finished with value: 0.735252376876328 and parameters: {'learning_rate': 0.032180800073458554, 'max_depth': 7, 'subsample': 0.681235382850731, 'colsample_bytree': 0.6408486008647359, 'min_child_weight': 10, 'gamma': 4.2576431012025315, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 1.2854923170194412, 'num_boost_round': 297}. Best is trial 24 with value: 0.7372918139132384.
# [I 2025-11-23 23:52:09,850] Trial 41 finished with value: 0.7367401184003359 and parameters: {'learning_rate': 0.012169689169505442, 'max_depth': 10, 'subsample': 0.604213099197713, 'colsample_bytree': 0.5332409450444118, 'min_child_weight': 1, 'gamma': 4.966173618189487, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 1.1152412302538843, 'num_boost_round': 432}. Best is trial 24 with value: 0.7372918139132384.
# [I 2025-11-23 23:52:13,071] Trial 42 finished with value: 0.7354389067063186 and parameters: {'learning_rate': 0.02418989454712546, 'max_depth': 10, 'subsample': 0.6415244069829857, 'colsample_bytree': 0.585725207236333, 'min_child_weight': 2, 'gamma': 4.727338843279804, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 0.9692279460572472, 'num_boost_round': 452}. Best is trial 24 with value: 0.7372918139132384.
# [I 2025-11-23 23:52:16,883] Trial 43 finished with value: 0.7364085950126678 and parameters: {'learning_rate': 0.012026228088788383, 'max_depth': 9, 'subsample': 0.731706994650522, 'colsample_bytree': 0.5356995501516851, 'min_child_weight': 1, 'gamma': 4.466388740981948, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 0.8330640029819308, 'num_boost_round': 475}. Best is trial 24 with value: 0.7372918139132384.
# [I 2025-11-23 23:52:19,516] Trial 44 finished with value: 0.7371936579096572 and parameters: {'learning_rate': 0.015815701536992504, 'max_depth': 10, 'subsample': 0.5993534263801835, 'colsample_bytree': 0.6003928323657524, 'min_child_weight': 2, 'gamma': 4.817644049071338, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 1.0272600122904696, 'num_boost_round': 394}. Best is trial 24 with value: 0.7372918139132384.
# [I 2025-11-23 23:52:21,688] Trial 45 finished with value: 0.7356189777709512 and parameters: {'learning_rate': 0.016130422691829436, 'max_depth': 9, 'subsample': 0.5491010069774185, 'colsample_bytree': 0.60466830915406, 'min_child_weight': 3, 'gamma': 4.6743203032886935, 'aft_loss_distribution': 'extreme', 'aft_loss_distribution_scale': 1.0715287360932333, 'num_boost_round': 385}. Best is trial 24 with value: 0.7372918139132384.
# [I 2025-11-23 23:52:25,566] Trial 46 finished with value: 0.7364520916869528 and parameters: {'learning_rate': 0.01030347916931862, 'max_depth': 10, 'subsample': 0.6731019790738202, 'colsample_bytree': 0.6469757001580231, 'min_child_weight': 1, 'gamma': 3.8381604776064284, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 1.0034441757051598, 'num_boost_round': 412}. Best is trial 24 with value: 0.7372918139132384.
# [I 2025-11-23 23:52:27,546] Trial 47 finished with value: 0.7360926674963599 and parameters: {'learning_rate': 0.021910033189764144, 'max_depth': 4, 'subsample': 0.7208410353652077, 'colsample_bytree': 0.5778159656712115, 'min_child_weight': 9, 'gamma': 4.285648406429823, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 0.8398756125588892, 'num_boost_round': 346}. Best is trial 24 with value: 0.7372918139132384.
# [I 2025-11-23 23:52:28,302] Trial 48 finished with value: 0.7343441085545048 and parameters: {'learning_rate': 0.018206532710021615, 'max_depth': 9, 'subsample': 0.5910169187392493, 'colsample_bytree': 0.6757062860364895, 'min_child_weight': 2, 'gamma': 4.757500790109325, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 1.0472426183285102, 'num_boost_round': 50}. Best is trial 24 with value: 0.7372918139132384.
# [I 2025-11-23 23:52:30,605] Trial 49 finished with value: 0.7361929283161126 and parameters: {'learning_rate': 0.015931114648868698, 'max_depth': 10, 'subsample': 0.6347784505609874, 'colsample_bytree': 0.6045875073871745, 'min_child_weight': 4, 'gamma': 4.05446434749393, 'aft_loss_distribution': 'logistic', 'aft_loss_distribution_scale': 0.7425004439362474, 'num_boost_round': 463}. Best is trial 24 with value: 0.7372918139132384.
# [I 2025-11-23 23:52:33,401] Trial 50 finished with value: 0.7328400601851844 and parameters: {'learning_rate': 0.031674561714135935, 'max_depth': 9, 'subsample': 0.760228845367911, 'colsample_bytree': 0.81183808491743, 'min_child_weight': 1, 'gamma': 2.6326181996473075, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 0.9465965130964837, 'num_boost_round': 392}. Best is trial 24 with value: 0.7372918139132384.
# [I 2025-11-23 23:52:35,982] Trial 51 finished with value: 0.7372945170560903 and parameters: {'learning_rate': 0.012112108850353156, 'max_depth': 10, 'subsample': 0.600226323848913, 'colsample_bytree': 0.5664989458466431, 'min_child_weight': 2, 'gamma': 4.884523153788995, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 1.088580879742662, 'num_boost_round': 433}. Best is trial 51 with value: 0.7372945170560903.
# [I 2025-11-23 23:52:38,958] Trial 52 finished with value: 0.7360714912479284 and parameters: {'learning_rate': 0.010020308422710757, 'max_depth': 10, 'subsample': 0.565733795620439, 'colsample_bytree': 0.568461332591264, 'min_child_weight': 3, 'gamma': 4.505655666914342, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 1.0964877004570321, 'num_boost_round': 372}. Best is trial 51 with value: 0.7372945170560903.
# [I 2025-11-23 23:52:41,234] Trial 53 finished with value: 0.7365090471147175 and parameters: {'learning_rate': 0.014148460363198903, 'max_depth': 10, 'subsample': 0.6985280850866452, 'colsample_bytree': 0.6304539993155992, 'min_child_weight': 2, 'gamma': 4.808990402324373, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 1.2532965058165642, 'num_boost_round': 426}. Best is trial 51 with value: 0.7372945170560903.
# [I 2025-11-23 23:52:44,256] Trial 54 finished with value: 0.7365214271766496 and parameters: {'learning_rate': 0.011733180327316715, 'max_depth': 9, 'subsample': 0.6347354315621179, 'colsample_bytree': 0.5351867354951091, 'min_child_weight': 1, 'gamma': 4.151263820142886, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 1.0395421103726394, 'num_boost_round': 457}. Best is trial 51 with value: 0.7372945170560903.
# [I 2025-11-23 23:52:46,912] Trial 55 finished with value: 0.7361822183579079 and parameters: {'learning_rate': 0.016157233212018816, 'max_depth': 10, 'subsample': 0.5958387745596655, 'colsample_bytree': 0.5888200456714616, 'min_child_weight': 5, 'gamma': 4.517103113180371, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 0.8633326547896829, 'num_boost_round': 481}. Best is trial 51 with value: 0.7372945170560903.
# [I 2025-11-23 23:52:49,382] Trial 56 finished with value: 0.7345291828967105 and parameters: {'learning_rate': 0.019202899388593844, 'max_depth': 10, 'subsample': 0.5305047305122224, 'colsample_bytree': 0.9317989624340886, 'min_child_weight': 2, 'gamma': 3.5369420792855273, 'aft_loss_distribution': 'extreme', 'aft_loss_distribution_scale': 1.412548011487004, 'num_boost_round': 402}. Best is trial 51 with value: 0.7372945170560903.
# [I 2025-11-23 23:52:51,413] Trial 57 finished with value: 0.7360952800993632 and parameters: {'learning_rate': 0.023744951906299674, 'max_depth': 9, 'subsample': 0.5615366732022921, 'colsample_bytree': 0.6611676874051079, 'min_child_weight': 3, 'gamma': 4.87004449379355, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 0.9579967155741584, 'num_boost_round': 305}. Best is trial 51 with value: 0.7372945170560903.
# [I 2025-11-23 23:52:54,590] Trial 58 finished with value: 0.7135550488282943 and parameters: {'learning_rate': 0.07041135996963409, 'max_depth': 8, 'subsample': 0.6646762136828325, 'colsample_bytree': 0.606741298992131, 'min_child_weight': 1, 'gamma': 0.38337172351945403, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 1.8082289602356545, 'num_boost_round': 432}. Best is trial 51 with value: 0.7372945170560903.
# [I 2025-11-23 23:52:56,074] Trial 59 finished with value: 0.7244958361352163 and parameters: {'learning_rate': 0.15352936480334198, 'max_depth': 9, 'subsample': 0.6937115414047219, 'colsample_bytree': 0.519129506175432, 'min_child_weight': 3, 'gamma': 4.662246180472601, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 0.6646991499774536, 'num_boost_round': 376}. Best is trial 51 with value: 0.7372945170560903.
# [I 2025-11-23 23:52:58,134] Trial 60 finished with value: 0.7356651545220094 and parameters: {'learning_rate': 0.0146188504298554, 'max_depth': 10, 'subsample': 0.5771548916615051, 'colsample_bytree': 0.5709522252320887, 'min_child_weight': 7, 'gamma': 3.202826617223405, 'aft_loss_distribution': 'logistic', 'aft_loss_distribution_scale': 1.1264933137377509, 'num_boost_round': 481}. Best is trial 51 with value: 0.7372945170560903.
# [I 2025-11-23 23:53:00,240] Trial 61 finished with value: 0.7358260715626597 and parameters: {'learning_rate': 0.013357102297115793, 'max_depth': 10, 'subsample': 0.6058399006972796, 'colsample_bytree': 0.5410961097067964, 'min_child_weight': 2, 'gamma': 4.8633363090979564, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 1.1998073003764285, 'num_boost_round': 436}. Best is trial 51 with value: 0.7372945170560903.
# [I 2025-11-23 23:53:02,539] Trial 62 finished with value: 0.7369699841713674 and parameters: {'learning_rate': 0.010945048859105319, 'max_depth': 10, 'subsample': 0.6296186057896467, 'colsample_bytree': 0.563508545355745, 'min_child_weight': 2, 'gamma': 4.984148712105687, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 1.1628778217166176, 'num_boost_round': 460}. Best is trial 51 with value: 0.7372945170560903.
# [I 2025-11-23 23:53:05,173] Trial 63 finished with value: 0.7377594910030734 and parameters: {'learning_rate': 0.011369520325451948, 'max_depth': 10, 'subsample': 0.629485316984003, 'colsample_bytree': 0.5647250234781622, 'min_child_weight': 6, 'gamma': 4.496069694424998, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 1.0615524508213205, 'num_boost_round': 462}. Best is trial 63 with value: 0.7377594910030734.
# [I 2025-11-23 23:53:07,309] Trial 64 finished with value: 0.7375223574337699 and parameters: {'learning_rate': 0.01659640986361119, 'max_depth': 9, 'subsample': 0.655600770731317, 'colsample_bytree': 0.5917369190423449, 'min_child_weight': 6, 'gamma': 4.398781967757653, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 1.0346760027126054, 'num_boost_round': 409}. Best is trial 63 with value: 0.7377594910030734.
# [I 2025-11-23 23:53:08,567] Trial 65 finished with value: 0.7362566369314347 and parameters: {'learning_rate': 0.016090639200407934, 'max_depth': 10, 'subsample': 0.6591461845107323, 'colsample_bytree': 0.6282798669105472, 'min_child_weight': 6, 'gamma': 4.394078279923196, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 1.042162087736244, 'num_boost_round': 128}. Best is trial 63 with value: 0.7377594910030734.
# [I 2025-11-23 23:53:10,732] Trial 66 finished with value: 0.7356748398396575 and parameters: {'learning_rate': 0.028531036873416224, 'max_depth': 9, 'subsample': 0.7237824741389494, 'colsample_bytree': 0.5165131216354324, 'min_child_weight': 6, 'gamma': 3.890856022507622, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 0.8767495416690814, 'num_boost_round': 412}. Best is trial 63 with value: 0.7377594910030734.
# [I 2025-11-23 23:53:13,853] Trial 67 finished with value: 0.7354932838630382 and parameters: {'learning_rate': 0.020163476932099755, 'max_depth': 10, 'subsample': 0.8961319543869526, 'colsample_bytree': 0.6146779726892256, 'min_child_weight': 8, 'gamma': 4.198431530316558, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 0.788617159795764, 'num_boost_round': 486}. Best is trial 63 with value: 0.7377594910030734.
# [I 2025-11-23 23:53:15,915] Trial 68 finished with value: 0.7362539004608608 and parameters: {'learning_rate': 0.011379511591496338, 'max_depth': 8, 'subsample': 0.6846532210772417, 'colsample_bytree': 0.5459744246529555, 'min_child_weight': 6, 'gamma': 4.567854957152867, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 1.2528807007979539, 'num_boost_round': 393}. Best is trial 63 with value: 0.7377594910030734.
# [I 2025-11-23 23:53:18,309] Trial 69 finished with value: 0.7375542511270613 and parameters: {'learning_rate': 0.01478343018030435, 'max_depth': 10, 'subsample': 0.6521489625415074, 'colsample_bytree': 0.5776415630437505, 'min_child_weight': 7, 'gamma': 3.6056782455589618, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 1.100505141606231, 'num_boost_round': 364}. Best is trial 63 with value: 0.7377594910030734.
# [I 2025-11-23 23:53:20,063] Trial 70 finished with value: 0.7352146980030347 and parameters: {'learning_rate': 0.022274294560607887, 'max_depth': 10, 'subsample': 0.6472942232184495, 'colsample_bytree': 0.5779875072857599, 'min_child_weight': 8, 'gamma': 3.6414390381450463, 'aft_loss_distribution': 'extreme', 'aft_loss_distribution_scale': 1.0822034693059477, 'num_boost_round': 339}. Best is trial 63 with value: 0.7377594910030734.
# [I 2025-11-23 23:53:22,797] Trial 71 finished with value: 0.7365118586017154 and parameters: {'learning_rate': 0.014554395336808969, 'max_depth': 10, 'subsample': 0.7081757540686066, 'colsample_bytree': 0.5622630325408202, 'min_child_weight': 7, 'gamma': 4.363039744239002, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 0.9106072941514239, 'num_boost_round': 412}. Best is trial 63 with value: 0.7377594910030734.
# [I 2025-11-23 23:53:24,813] Trial 72 finished with value: 0.7369324130290597 and parameters: {'learning_rate': 0.018157256141755094, 'max_depth': 10, 'subsample': 0.6248395404750018, 'colsample_bytree': 0.5944457611255068, 'min_child_weight': 7, 'gamma': 4.160895703534898, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 1.1083933686465097, 'num_boost_round': 364}. Best is trial 63 with value: 0.7377594910030734.
# [I 2025-11-23 23:53:28,145] Trial 73 finished with value: 0.7346973960030161 and parameters: {'learning_rate': 0.017067585194555587, 'max_depth': 10, 'subsample': 0.5830336163963996, 'colsample_bytree': 0.5798744662914728, 'min_child_weight': 6, 'gamma': 2.3063084102058693, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 1.0081764846710695, 'num_boost_round': 401}. Best is trial 63 with value: 0.7377594910030734.
# [I 2025-11-23 23:53:30,843] Trial 74 finished with value: 0.7349039373587825 and parameters: {'learning_rate': 0.013428709476660588, 'max_depth': 9, 'subsample': 0.666054991726388, 'colsample_bytree': 0.8726305612993639, 'min_child_weight': 5, 'gamma': 3.8992025495005325, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 1.1411286876580684, 'num_boost_round': 423}. Best is trial 63 with value: 0.7377594910030734.
# [I 2025-11-23 23:53:33,115] Trial 75 finished with value: 0.7362994029706311 and parameters: {'learning_rate': 0.014733537011858326, 'max_depth': 6, 'subsample': 0.7646918373283647, 'colsample_bytree': 0.6507191202722874, 'min_child_weight': 7, 'gamma': 4.625162051879045, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 0.9908928946742563, 'num_boost_round': 355}. Best is trial 63 with value: 0.7377594910030734.
# [I 2025-11-23 23:53:36,637] Trial 76 finished with value: 0.7347583753609024 and parameters: {'learning_rate': 0.010876664718732852, 'max_depth': 9, 'subsample': 0.6795031847122115, 'colsample_bytree': 0.5535176261696818, 'min_child_weight': 5, 'gamma': 1.8520386838158096, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 1.2014514633945683, 'num_boost_round': 381}. Best is trial 63 with value: 0.7377594910030734.
# [I 2025-11-23 23:53:38,719] Trial 77 finished with value: 0.7358522061541025 and parameters: {'learning_rate': 0.012909587729903338, 'max_depth': 10, 'subsample': 0.6475881288123765, 'colsample_bytree': 0.6172347826102056, 'min_child_weight': 6, 'gamma': 4.452046472486147, 'aft_loss_distribution': 'logistic', 'aft_loss_distribution_scale': 0.9319344547202414, 'num_boost_round': 468}. Best is trial 63 with value: 0.7377594910030734.
# [I 2025-11-23 23:53:40,411] Trial 78 finished with value: 0.7365949884768425 and parameters: {'learning_rate': 0.01956379627721151, 'max_depth': 10, 'subsample': 0.6179995742844407, 'colsample_bytree': 0.6308192475591826, 'min_child_weight': 8, 'gamma': 4.306106886938152, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 1.2951744202159814, 'num_boost_round': 255}. Best is trial 63 with value: 0.7377594910030734.
# [I 2025-11-23 23:53:42,818] Trial 79 finished with value: 0.7380068602938252 and parameters: {'learning_rate': 0.016980516851956066, 'max_depth': 9, 'subsample': 0.6029234629839031, 'colsample_bytree': 0.506014005892288, 'min_child_weight': 4, 'gamma': 4.855038784466753, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 1.0785875074347213, 'num_boost_round': 451}. Best is trial 79 with value: 0.7380068602938252.
# [I 2025-11-23 23:53:45,187] Trial 80 finished with value: 0.737883772249624 and parameters: {'learning_rate': 0.017189270909388096, 'max_depth': 9, 'subsample': 0.5556914096554342, 'colsample_bytree': 0.5063794415761449, 'min_child_weight': 4, 'gamma': 4.868286305754805, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 1.0462988301289882, 'num_boost_round': 487}. Best is trial 79 with value: 0.7380068602938252.
# [I 2025-11-23 23:53:47,445] Trial 81 finished with value: 0.7376339723799926 and parameters: {'learning_rate': 0.017199826675549108, 'max_depth': 9, 'subsample': 0.5974118061557022, 'colsample_bytree': 0.524826048451655, 'min_child_weight': 4, 'gamma': 4.847894825683437, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 1.0244376456356963, 'num_boost_round': 493}. Best is trial 79 with value: 0.7380068602938252.
# [I 2025-11-23 23:53:49,671] Trial 82 finished with value: 0.7375137584828851 and parameters: {'learning_rate': 0.01713594854264032, 'max_depth': 8, 'subsample': 0.5536783387085124, 'colsample_bytree': 0.5138752689070366, 'min_child_weight': 4, 'gamma': 4.836710976730865, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 1.0670096843082362, 'num_boost_round': 490}. Best is trial 79 with value: 0.7380068602938252.
# [I 2025-11-23 23:53:51,757] Trial 83 finished with value: 0.7375460631293839 and parameters: {'learning_rate': 0.0172224815008657, 'max_depth': 8, 'subsample': 0.5468446912041399, 'colsample_bytree': 0.5000928836182013, 'min_child_weight': 4, 'gamma': 4.881974346548023, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 1.0717558440418145, 'num_boost_round': 489}. Best is trial 79 with value: 0.7380068602938252.
# [I 2025-11-23 23:53:53,926] Trial 84 finished with value: 0.7380209021818651 and parameters: {'learning_rate': 0.016933974706785038, 'max_depth': 8, 'subsample': 0.5001712837921908, 'colsample_bytree': 0.5053505855803628, 'min_child_weight': 4, 'gamma': 4.877881834256535, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 1.0893020950710495, 'num_boost_round': 488}. Best is trial 84 with value: 0.7380209021818651.
# [I 2025-11-23 23:53:55,952] Trial 85 finished with value: 0.7369471304481781 and parameters: {'learning_rate': 0.02315561992939325, 'max_depth': 8, 'subsample': 0.5205495762433677, 'colsample_bytree': 0.5053295677852074, 'min_child_weight': 4, 'gamma': 4.658093655589376, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 1.0695820720871876, 'num_boost_round': 489}. Best is trial 84 with value: 0.7380209021818651.
# [I 2025-11-23 23:53:58,406] Trial 86 finished with value: 0.7381156386425943 and parameters: {'learning_rate': 0.017642376367102357, 'max_depth': 8, 'subsample': 0.5020697337877092, 'colsample_bytree': 0.523845579038552, 'min_child_weight': 4, 'gamma': 4.7592018567856496, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 1.121930248100547, 'num_boost_round': 490}. Best is trial 86 with value: 0.7381156386425943.
# [I 2025-11-23 23:54:00,553] Trial 87 finished with value: 0.7371614729635599 and parameters: {'learning_rate': 0.026052128861936693, 'max_depth': 7, 'subsample': 0.5008372789225616, 'colsample_bytree': 0.5005480296728121, 'min_child_weight': 4, 'gamma': 4.724440360572908, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 1.2177514530530393, 'num_boost_round': 470}. Best is trial 86 with value: 0.7381156386425943.
# [I 2025-11-23 23:54:03,233] Trial 88 finished with value: 0.7366758349353069 and parameters: {'learning_rate': 0.015211626429989215, 'max_depth': 8, 'subsample': 0.5379042968538797, 'colsample_bytree': 0.5272176087451675, 'min_child_weight': 5, 'gamma': 4.523614483967387, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 1.1648231543177097, 'num_boost_round': 499}. Best is trial 86 with value: 0.7381156386425943.
# [I 2025-11-23 23:54:05,656] Trial 89 finished with value: 0.7375288185692741 and parameters: {'learning_rate': 0.018426842172179617, 'max_depth': 7, 'subsample': 0.5185084244958807, 'colsample_bytree': 0.5256457443098582, 'min_child_weight': 4, 'gamma': 4.904782215350232, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 1.1197104328153282, 'num_boost_round': 477}. Best is trial 86 with value: 0.7381156386425943.
# [I 2025-11-23 23:54:07,957] Trial 90 finished with value: 0.735624134525591 and parameters: {'learning_rate': 0.018778408497616507, 'max_depth': 7, 'subsample': 0.5206351977394877, 'colsample_bytree': 0.5285262422518295, 'min_child_weight': 4, 'gamma': 4.995580209999215, 'aft_loss_distribution': 'extreme', 'aft_loss_distribution_scale': 1.1302750253300513, 'num_boost_round': 478}. Best is trial 86 with value: 0.7381156386425943.
# [I 2025-11-23 23:54:10,676] Trial 91 finished with value: 0.7362184258335029 and parameters: {'learning_rate': 0.016599691149610147, 'max_depth': 7, 'subsample': 0.5301923806283738, 'colsample_bytree': 0.511742373007996, 'min_child_weight': 4, 'gamma': 4.742189768339989, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 1.0131770021131992, 'num_boost_round': 465}. Best is trial 86 with value: 0.7381156386425943.
# [I 2025-11-23 23:54:13,098] Trial 92 finished with value: 0.7389229744536877 and parameters: {'learning_rate': 0.020645681310170697, 'max_depth': 8, 'subsample': 0.5088429881881916, 'colsample_bytree': 0.5450737154385423, 'min_child_weight': 4, 'gamma': 4.870517959960257, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 1.1052131986964089, 'num_boost_round': 453}. Best is trial 92 with value: 0.7389229744536877.
# [I 2025-11-23 23:54:15,654] Trial 93 finished with value: 0.7385059700849493 and parameters: {'learning_rate': 0.01771773808021272, 'max_depth': 8, 'subsample': 0.5098996440868019, 'colsample_bytree': 0.5429273195130427, 'min_child_weight': 4, 'gamma': 4.856637311756328, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 1.0982497580400357, 'num_boost_round': 450}. Best is trial 92 with value: 0.7389229744536877.
# [I 2025-11-23 23:54:17,974] Trial 94 finished with value: 0.7366360963807674 and parameters: {'learning_rate': 0.024782632983032064, 'max_depth': 8, 'subsample': 0.5054583852417662, 'colsample_bytree': 0.5465670189004136, 'min_child_weight': 5, 'gamma': 4.613174897813002, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 1.1771189172429921, 'num_boost_round': 450}. Best is trial 92 with value: 0.7389229744536877.
# [I 2025-11-23 23:54:21,198] Trial 95 finished with value: 0.7361398992913865 and parameters: {'learning_rate': 0.020694484136521148, 'max_depth': 8, 'subsample': 0.5474685597706986, 'colsample_bytree': 0.5001181987832535, 'min_child_weight': 4, 'gamma': 4.811005186011597, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 0.9907744953461308, 'num_boost_round': 457}. Best is trial 92 with value: 0.7389229744536877.
# [I 2025-11-23 23:54:23,754] Trial 96 finished with value: 0.7369886599964854 and parameters: {'learning_rate': 0.014767051238913757, 'max_depth': 8, 'subsample': 0.5327476867713382, 'colsample_bytree': 0.5391458784197356, 'min_child_weight': 5, 'gamma': 4.741184104614998, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 1.234545371039314, 'num_boost_round': 489}. Best is trial 92 with value: 0.7389229744536877.
# [I 2025-11-23 23:54:26,466] Trial 97 finished with value: 0.7375519446650873 and parameters: {'learning_rate': 0.013746393322468584, 'max_depth': 8, 'subsample': 0.5733835265193173, 'colsample_bytree': 0.5169293579995464, 'min_child_weight': 4, 'gamma': 4.8851380990916375, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 1.097352924644826, 'num_boost_round': 471}. Best is trial 92 with value: 0.7389229744536877.
# [I 2025-11-23 23:54:28,616] Trial 98 finished with value: 0.736387021139927 and parameters: {'learning_rate': 0.013981562868578674, 'max_depth': 8, 'subsample': 0.5746736594756443, 'colsample_bytree': 0.5198486998793289, 'min_child_weight': 4, 'gamma': 4.532227324574137, 'aft_loss_distribution': 'logistic', 'aft_loss_distribution_scale': 0.9792497272177682, 'num_boost_round': 450}. Best is trial 92 with value: 0.7389229744536877.
# [I 2025-11-23 23:54:31,348] Trial 99 finished with value: 0.7383659994610798 and parameters: {'learning_rate': 0.012748342252461228, 'max_depth': 8, 'subsample': 0.5118821336790563, 'colsample_bytree': 0.5374584338353207, 'min_child_weight': 3, 'gamma': 4.657205881885364, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 1.0941897812966728, 'num_boost_round': 442}. Best is trial 92 with value: 0.7389229744536877.

# %%
print("Meilleurs hyperparamètres:")
print(study.best_params)
print(f"\nMeilleur C-index moyen: {study.best_value:.4f}")
# Out:
# Meilleurs hyperparamètres:
# {'learning_rate': 0.020645681310170697, 'max_depth': 8, 'subsample': 0.5088429881881916, 'colsample_bytree': 0.5450737154385423, 'min_child_weight': 4, 'gamma': 4.870517959960257, 'aft_loss_distribution': 'normal', 'aft_loss_distribution_scale': 1.1052131986964089, 'num_boost_round': 453}
#
# Meilleur C-index moyen: 0.7389

# %%
best_params = study.best_params
best_params["objective"] = "survival:aft"
best_params["eval_metric"] = "aft-nloglik"
best_params["tree_method"] = "hist"
best_params["seed"] = 42

best_num_boost_round = best_params.pop("num_boost_round")

# %%
lb_full_final = y_full_log_time.copy()
ub_full_final = y_full_log_time.copy()
ub_full_final[event_vals == 0] = np.inf

dfull_final = xgb.DMatrix(X_full)
dfull_final.set_float_info("label_lower_bound", lb_full_final)
dfull_final.set_float_info("label_upper_bound", ub_full_final)

model_tuned = xgb.train(
    best_params,
    dfull_final,
    num_boost_round=best_num_boost_round,
    verbose_eval=False
)

# %%
X_eval_final = eval_enhanced[feature_cols].fillna(0.0).to_numpy(dtype=float)
deval_final = xgb.DMatrix(X_eval_final)

y_pred_log_eval_tuned = model_tuned.predict(deval_final)
risk_score_tuned = -y_pred_log_eval_tuned

submission_tuned = pd.DataFrame({
    'ID': eval_enhanced['ID'],
    'risk_score': risk_score_tuned
})

submission_tuned.to_csv('../submissions/submission_xgb_aft_tuned.csv', index=False)
print("Prédictions avec hyperparamètres optimisés sauvegardées dans '../submissions/submission_xgb_aft_tuned.csv'")
# Out:
# Prédictions avec hyperparamètres optimisés sauvegardées dans '../submissions/submission_xgb_aft_tuned.csv'

# %%
import plotly.express as px

fig = optuna.visualization.plot_optimization_history(study)
fig.show()

# %%
fig = optuna.visualization.plot_param_importances(study)
fig.show()
