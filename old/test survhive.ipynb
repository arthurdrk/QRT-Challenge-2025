# %%
import sys
import os
sys.path.append(os.path.join(os.getcwd(), 'survhive'))

import survhive as sv

dataset = pd.read_csv('data/df_train.csv')

# %%
from sksurv.datasets import get_x_y
X, y = get_x_y(dataset, 
               attr_labels=['OS_STATUS','OS_YEARS'], 
               pos_label=True)

# %%
import sys
sys.path.append('./survhive')
import survhive as sv

# Test de la fonction
X_train, X_test, y_train, y_test = sv.util.survival_train_test_split(X, y, rng_seed=42)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 6
#       3 import survhive as sv
#       5 # Test de la fonction
# ----> 6 X_train, X_test, y_train, y_test = sv.util.survival_train_test_split(X, y, rng_seed=42)
#
# AttributeError: module 'survhive' has no attribute 'util'
