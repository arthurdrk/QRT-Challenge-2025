# %%
import pandas as pd

# Charger les deux fichiers
df1 = pd.read_csv('C:\\Users\\arthr\\Desktop\\ENSAE\\QRT-Challenge-2025\\submissions\\XGB_0.7623.csv')
df2 = pd.read_csv('C:\\Users\\arthr\\Desktop\\ENSAE\\QRT-Challenge-2025\\submissions\\xgb-cindex-tuned_0.753.csv')

# Vérifier que les IDs sont dans le même ordre
assert all(df1['ID'] == df2['ID'])

# Calculer la moyenne des risk_score
df_mean = df1.copy()
df_mean['risk_score'] = (2.8*df1['risk_score'] + df2['risk_score']) / 3.8

# Sauvegarder le résultat
df_mean.to_csv('submissions/XGBAFT_XGBCindex.csv', index=False)
